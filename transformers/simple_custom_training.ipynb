# %% [markdown]
# **참고문헌**
# \[1\] [16-01 트랜스포머(Transformer)](https://wikidocs.net/31379)
# \[2\] [The Annotated Transformer](https://nlp.seas.harvard.edu/2018/04/03/attention.html#prelims)

# %%
from transformers import *
from konlpy.tag import Okt
import spacy
import numpy as np
import time
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch.nn.utils.rnn import pad_sequence
from torch.autograd import Variable
from functools import partial
import seaborn
seaborn.set_context(context="talk")
# %matplotlib inline

# %% [markdown]
# ![](../images/the-annotated-transformer_14_0.png)
#
#
#
# Figure 1: The Transformer - model architecture.

# %%
okt = Okt()
nlp = spacy.load("en_core_web_sm")
special_tokens = ["<pad>", "<unk>", "<sos>", "<eos>"]

# %%
parallel_corpus = [
    {"en": "Hello.", "ko": "안녕하세요."},
    {"en": "How are you?", "ko": "잘 지내세요?"},
    {"en": "I am a student.", "ko": "저는 학생입니다."},
    {"en": "What is your name?", "ko": "당신의 이름은 무엇인가요?"},
    {"en": "My name is John.", "ko": "제 이름은 존입니다."},
    {"en": "Nice to meet you.", "ko": "만나서 반갑습니다."},
    {"en": "Good morning!", "ko": "좋은 아침이에요!"},
    {"en": "Good night.", "ko": "안녕히 주무세요."},
    {"en": "Where are you going?", "ko": "어디 가세요?"},
    {"en": "I’m going home.", "ko": "집에 가는 중이에요."},
    {"en": "See you later.", "ko": "나중에 봐요."},
    {"en": "Thank you very much.", "ko": "정말 감사합니다."},
    {"en": "You're welcome.", "ko": "천만에요."},
    {"en": "Excuse me.", "ko": "실례합니다."},
    {"en": "I’m sorry.", "ko": "죄송합니다."},
    {"en": "No problem.", "ko": "괜찮아요."},
    {"en": "Do you speak English?", "ko": "영어 할 줄 아세요?"},
    {"en": "I speak a little Korean.", "ko": "한국어 조금 할 줄 알아요."},
    {"en": "How much is this?", "ko": "이거 얼마예요?"},
    {"en": "Where is the restroom?", "ko": "화장실 어디예요?"},
    {"en": "Can you help me?", "ko": "도와주실 수 있나요?"},
    {"en": "I don’t understand.", "ko": "이해하지 못했어요."},
    {"en": "Please speak slowly.", "ko": "천천히 말씀해 주세요."},
    {"en": "I’m hungry.", "ko": "배고파요."},
    {"en": "I’m tired.", "ko": "피곤해요."},
    {"en": "What time is it?", "ko": "지금 몇 시예요?"},
    {"en": "Today is Monday.", "ko": "오늘은 월요일이에요."},
    {"en": "It’s raining.", "ko": "비가 오고 있어요."},
    {"en": "I like music.", "ko": "저는 음악을 좋아해요."},
    {"en": "Let’s go together.", "ko": "같이 가요."},
    {"en": "Have a nice day!", "ko": "좋은 하루 되세요!"},
    {"en": "Goodbye!", "ko": "안녕히 가세요!"}
]

# %% [markdown]
# ``` python
# class Batch:
#     "Object for holding a batch of data with mask during training."
#     def __init__(self, src, trg=None, pad=0, device=torch.device("cpu")):
#         self.src = src.to(device)
#         self.src_mask = (src != pad).unsqueeze(-2).to(device)
#         if trg is not None:
#             self.trg = trg[:, :-1].to(device)
#             self.trg_y = trg[:, 1:].to(device)
#             self.trg_mask = \
#                 self.make_std_mask(self.trg, pad).to(device)
#             self.ntokens = (self.trg_y != pad).data.sum()
#
#     @staticmethod
#     def make_std_mask(tgt, pad):
#         "Create a mask to hide padding and future words."
#         tgt_mask = (tgt != pad).unsqueeze(-2)
#         #print('tgt_mask.shape', tgt_mask.shape)
#         #print('tgt_mask', tgt_mask)
#         tgt_mask = tgt_mask & Variable(
#             subsequent_mask(tgt.size(-1)).type_as(tgt_mask.data))
#         return tgt_mask
# ```

# %%
class En2KoDataset(Dataset):
    def __init__(self, corpus, okt, nlp, random=False, special_tokens = ["<pad>", "<unk>", "<sos>", "<eos>"]):
        
        self.random = random
        
        self.src_sentences = []
        self.trg_sentences = []
        
        self.en_tokens = set()
        self.ko_tokens = set()
        for line in parallel_corpus:
            self.trg_sentences.append(line['en'])
            self.src_sentences.append(line['ko'])
            self.ko_tokens.update(okt.morphs(line['ko']))
            en_list = [ token.text for token in nlp(line['en'])]
            self.en_tokens.update(en_list)
    
        self.special_tokens = special_tokens
    
        self.en_vocab = special_tokens + sorted(list(self.en_tokens))
        self.en_token2idx = {token: idx for idx, token in enumerate(self.en_vocab)}
        self.en_idx2token = {idx: token for token, idx in self.en_token2idx.items()}
        
        self.ko_vocab = special_tokens + sorted(list(self.ko_tokens))
        self.ko_token2idx = {token: idx for idx, token in enumerate(self.ko_vocab)}
        self.ko_idx2token = {idx: token for token, idx in self.ko_token2idx.items()}

        self.n_en_vocab = len(self.en_vocab)
        self.n_ko_vocab = len(self.ko_vocab)
        
        self.srcs = []
        self.trgs = []
        #self.trgs_y = []
        
        for line in parallel_corpus:
            trg = self.en_encode(line['en'], self.en_token2idx)
            self.trgs.append(trg)
            #self.trgs_y.append(trg[1:])
            src = self.ko_encode(line['ko'], self.ko_token2idx) 
            self.srcs.append(src)

        self.n_sentences = len(self.src_sentences) 
        print(self.n_sentences)
            
    def ko_encode(self, sentence, token2idx):
        tokens = okt.morphs(sentence)
        ids = [token2idx.get(tok, token2idx["<unk>"]) for tok in tokens]
        out = None
        out = [token2idx["<sos>"]] + ids + [token2idx["<eos>"]]   
        return out


    def en_encode(self, sentence, token2idx):
        tokens = [ token.text for token in nlp(sentence)]
        ids = [token2idx.get(tok, token2idx["<unk>"]) for tok in tokens]
        out = None
        out = [token2idx["<sos>"]] + ids + [token2idx["<eos>"]]   
        return out

    def __len__(self):
        return len(self.src_sentences)


    def __getitem__(self, index):
        #print(f"index: {index}")
        # if self.random:
        #     t = int(time.time() * 1000000)
        #     np.random.seed(((t & 0xff000000) >> 24) +
        #                    ((t & 0x00ff0000) >> 8) +
        #                    ((t & 0x0000ff00) << 8) +
        #                    ((t & 0x000000ff) << 24))
        #     index = np.random.randint(self.n_sentences)
        # else:
        #     index = index % self.n_sentences
        #     pass
        #index = index % self.__len__()
        
        sample = self.srcs[index], self.trgs[index]
        return sample

def custom_collate_fn(raw_data, device):
    srcs, trgs = zip(*raw_data)  # unpack batch list of triples

    srcs = [torch.tensor(seq) for seq in srcs]
    trgs = [torch.tensor(seq) for seq in trgs]

    srcs_padded = pad_sequence(srcs, batch_first=True, padding_value=0)
    trgs_padded = pad_sequence(trgs, batch_first=True, padding_value=0)
    
    return Batch(srcs_padded, trgs_padded, pad=0, device=device)

# %% [markdown]
# ``` python
# def run_epoch(data_iter, model, loss_compute):
#     "Standard Training and Logging Function"
#     start = time.time()
#     total_tokens = 0
#     total_loss = 0
#     tokens = 0
#     for i, batch in enumerate(data_iter):
#         print(f"i: {i}")
#         out = model.forward(batch.src, batch.trg,
#                             batch.src_mask, batch.trg_mask)
#         #print(f'trg_y.shape: {batch.trg_y.shape}')
#         loss = loss_compute(out, batch.trg_y, batch.ntokens)
#         total_loss += loss
#         total_tokens += batch.ntokens
#         tokens += batch.ntokens
#         if i % 50 == 0:
#             elapsed = time.time() - start
#             print("Epoch Step: %d Loss: %f Tokens per Sec: %f" %
#                     (i, loss / batch.ntokens, tokens / elapsed))
#             start = time.time()
#             tokens = 0
#     return total_loss / total_tokens
# #```

# %% [markdown]
# ## loading datasets:

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
collate_with_device = partial(custom_collate_fn, device=device)
dataset = En2KoDataset(parallel_corpus, okt, nlp)
loader = DataLoader(dataset, batch_size=32, shuffle=True, collate_fn=collate_with_device)
# Out:
# 32

# %% [markdown]
# ### Set hyperpameters

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
collate_with_device = partial(custom_collate_fn, device=device)
dataset = En2KoDataset(parallel_corpus, okt, nlp)
loader = DataLoader(dataset, batch_size=32, shuffle=True, collate_fn=collate_with_device)
N=2
n_src_vocab = dataset.n_ko_vocab
n_tgt_vocab = dataset.n_en_vocab
d_ff = 2048
d_model=512
d_ff=2048
h=8
dropout=0.1
# Out:
# 32

# %% [markdown]
# ### trainning

# %%
criterion = LabelSmoothing(size=n_tgt_vocab, padding_idx=0, smoothing=0.0)
model = make_model(n_src_vocab, n_tgt_vocab,  N=2)
model = model.to(device)
model_opt = NoamOpt(model.src_embed[0].d_model, 1, 400,
        torch.optim.Adam(model.parameters(), lr=0, betas=(0.9, 0.98), eps=1e-9))
for epoch in range(1000):
    model.train()
    run_epoch(loader, model, 
              SimpleLossCompute(model.generator, criterion, model_opt))
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# /home/developer/npl_tutorials/transformers/transformers.py:248: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.
#   nn.init.xavier_uniform(p)
# Epoch Step: 0 Loss: 4.690696 Tokens per Sec: 325.193268
# Epoch Step: 0 Loss: 4.479691 Tokens per Sec: 6148.725586
# Epoch Step: 0 Loss: 4.293833 Tokens per Sec: 6794.901855
# Epoch Step: 0 Loss: 4.219559 Tokens per Sec: 6069.280762
# Epoch Step: 0 Loss: 3.943329 Tokens per Sec: 6461.363281
# Epoch Step: 0 Loss: 3.753908 Tokens per Sec: 6479.791992
# Epoch Step: 0 Loss: 3.607972 Tokens per Sec: 5946.522461
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6714.636719
# Epoch Step: 0 Loss: 0.000002 Tokens per Sec: 6807.561523
# Epoch Step: 0 Loss: 0.000002 Tokens per Sec: 6189.746094
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6719.410645
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6456.419434
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6587.463379
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6242.183594
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6291.661133
# Epoch Step: 0 Loss: 0.000002 Tokens per Sec: 6060.718750
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6390.067383
# Epoch Step: 0 Loss: 0.000002 Tokens per Sec: 5988.319336
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6257.667969
# Epoch Step: 0 Loss: 0.000002 Tokens per Sec: 6284.464844
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6599.115234
# Epoch Step: 0 Loss: 0.000002 Tokens per Sec: 6751.475586
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6695.356445
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6725.020508
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6228.033203
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6242.623047
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6288.757812
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6540.659180
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6447.492676
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6698.267090
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6653.313965
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6352.443359
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 5942.384766
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 5944.926758
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6749.674805
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6832.891602
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6632.955566
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6945.980957
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6519.843750
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6921.361328
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6220.108887
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6688.912109
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6657.250488
# Epoch Step: 0 Loss: 0.000002 Tokens per Sec: 6725.786621
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6663.508301
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6946.594238
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6926.704102
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 7033.791504
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6400.395508
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6393.641113
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6687.334473
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6800.639160
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 7046.867676
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 5930.849609
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 7060.977051
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6681.094727
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6495.824707
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6732.302246
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 7001.208496
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6910.429688
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6908.813477
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6972.216309
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6656.687500
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6877.375488
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6471.036621
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6387.418457
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6994.990723
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 7069.145996
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6913.059082
# Epoch Step: 0 Loss: 0.000002 Tokens per Sec: 6715.463867
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 7086.177246
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6725.850586
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6135.101562
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6325.403809
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6785.210449
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6815.875488
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6799.007812
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6804.816895
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6681.346191
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6588.136230
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6037.025879
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6295.963867
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 7056.689453
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6793.794922
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6089.877441
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6864.654785
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6652.938477
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6733.772949
# Epoch Step: 0 Loss: 0.000001 Tokens per Sec: 6216.999023
# Epoch Step: 0 Loss: 0.000000 Tokens per Sec: 3123.718750
# Epoch Step: 0 Loss: 0.000000 Tokens per Sec: 4927.614746
# Epoch Step: 0 Loss: 0.000000 Tokens per Sec: 4841.289551
# Epoch Step: 0 Loss: 0.000000 Tokens per Sec: 5817.342773
# Epoch Step: 0 Loss: 0.000000 Tokens per Sec: 6372.717773
# Epoch Step: 0 Loss: 0.000000 Tokens per Sec: 5525.919922
# Epoch Step: 0 Loss: 0.000000 Tokens per Sec: 5878.955078
# Epoch Step: 0 Loss: 0.000000 Tokens per Sec: 6205.623535
# Epoch Step: 0 Loss: 0.000000 Tokens per Sec: 6353.354004
# Epoch Step: 0 Loss: 0.000000 Tokens per Sec: 6609.884277
# Epoch Step: 0 Loss: 0.000000 Tokens per Sec: 6431.463867
# Epoch Step: 0 Loss: 0.000000 Tokens per Sec: 6758.298828
# Epoch Step: 0 Loss: 0.000000 Tokens per Sec: 6093.646973
# Epoch Step: 0 Loss: 0.000000 Tokens per Sec: 5734.791016
# Epoch Step: 0 Loss: 0.000000 Tokens per Sec: 5818.774902
# Epoch Step: 0 Loss: 0.000000 Tokens per Sec: 5179.590820

# %% [markdown]
# ### greedy decoding

# %%
def greedy_decode(model, src, src_mask, max_len, start_symbol):
    memory = model.encode(src, src_mask)
    ys = torch.ones(1, 1).fill_(start_symbol).type_as(src.data)
    for i in range(max_len-1):
        #print(ys)
        out = model.decode(memory, src_mask, 
                           Variable(ys), 
                           Variable(subsequent_mask(ys.size(1))
                                    .type_as(src.data)))
        #print(f"out shape: {out.shape}")
        #print(f"out[:-1] shape: {out[:, -1].shape}")
        prob = model.generator(out[:, -1])
        #print(f"prob shape: {prob.shape}")
        _, next_word = torch.max(prob, dim = 1)
        next_word = next_word.data[0]
        ys = torch.cat([ys, 
                        torch.ones(1, 1).type_as(src.data).fill_(next_word)], dim=1)
    return ys

# %%
model.eval()

print(f"input : {dataset.src_sentences[0]}")
print(f"output : {dataset.trg_sentences[0]}")

srcs = [torch.tensor(seq) for seq in dataset[0][0]]
src = Variable(torch.LongTensor([srcs]).unsqueeze(0) ).to(device)
src_mask = Variable(torch.ones(1, 1, len(srcs) )).to(device)
#print(greedy_decode(model, src, src_mask, max_len=10, start_symbol=2))

result = greedy_decode(model, src, src_mask, max_len=10, start_symbol=2)
res = result.detach().cpu().numpy()[0] 
print("predict : ", end=" ")
for r in res.tolist():
    if dataset.en_idx2token[r] == '<sos>':
        continue
    elif dataset.en_idx2token[r] == '<eos>':
        break;
    print(dataset.en_idx2token[r],end=" ")
# Out:
# input : 안녕하세요.
# output : Hello.
# predict :  Hello .

# %%
print("results for simple translator.")
print("-------------------------------------------------------------------------------\n
")
for i, _ in enumerate(dataset):
    print(f"input : {dataset.src_sentences[i]}")
    print(f"output : {dataset.trg_sentences[i]}")
    
    srcs = [torch.tensor(seq) for seq in dataset[i][0]]
    src = Variable(torch.LongTensor([srcs]).unsqueeze(0) ).to(device)
    src_mask = Variable(torch.ones(1, 1, len(srcs) )).to(device)
    #print(greedy_decode(model, src, src_mask, max_len=10, start_symbol=2))
    
    result = greedy_decode(model, src, src_mask, max_len=10, start_symbol=2)
    res = result.detach().cpu().numpy()[0] 
    print("predict : ", end=" ")
    for r in res.tolist():
        if dataset.en_idx2token[r] == '<sos>':
            continue
        elif dataset.en_idx2token[r] == '<eos>':
            break;
        print(dataset.en_idx2token[r],end=" ")
    print("")
    print("-------------------------------------------------------------------------------")
# Out:
# results for simple translator.
# -------------------------------------------------------------------------------
#
# input : 안녕하세요.
# output : Hello.
# predict :  Hello .
# -------------------------------------------------------------------------------
# input : 잘 지내세요?
# output : How are you?
# predict :  How are you ?
# -------------------------------------------------------------------------------
# input : 저는 학생입니다.
# output : I am a student.
# predict :  I am a student .
# -------------------------------------------------------------------------------
# input : 당신의 이름은 무엇인가요?
# output : What is your name?
# predict :  What is your name ?
# -------------------------------------------------------------------------------
# input : 제 이름은 존입니다.
# output : My name is John.
# predict :  My name is John .
# -------------------------------------------------------------------------------
# input : 만나서 반갑습니다.
# output : Nice to meet you.
# predict :  Nice to meet you .
# -------------------------------------------------------------------------------
# input : 좋은 아침이에요!
# output : Good morning!
# predict :  Good morning !
# -------------------------------------------------------------------------------
# input : 안녕히 주무세요.
# output : Good night.
# predict :  Good night .
# -------------------------------------------------------------------------------
# input : 어디 가세요?
# output : Where are you going?
# predict :  Where are you going ?
# -------------------------------------------------------------------------------
# input : 집에 가는 중이에요.
# output : I’m going home.
# predict :  I ’m going home .
# -------------------------------------------------------------------------------
# input : 나중에 봐요.
# output : See you later.
# predict :  See you later .
# -------------------------------------------------------------------------------
# input : 정말 감사합니다.
# output : Thank you very much.
# predict :  Thank you very much .
# -------------------------------------------------------------------------------
# input : 천만에요.
# output : You're welcome.
# predict :  You 're welcome .
# -------------------------------------------------------------------------------
# input : 실례합니다.
# output : Excuse me.
# predict :  Excuse me .
# -------------------------------------------------------------------------------
# input : 죄송합니다.
# output : I’m sorry.
# predict :  I ’m sorry .
# -------------------------------------------------------------------------------
# input : 괜찮아요.
# output : No problem.
# predict :  No problem .
# -------------------------------------------------------------------------------
# input : 영어 할 줄 아세요?
# output : Do you speak English?
# predict :  Do you speak English ?
# -------------------------------------------------------------------------------
# input : 한국어 조금 할 줄 알아요.
# output : I speak a little Korean.
# predict :  I speak a little Korean .
# -------------------------------------------------------------------------------
# input : 이거 얼마예요?
# output : How much is this?
# predict :  How much is this ?
# -------------------------------------------------------------------------------
# input : 화장실 어디예요?
# output : Where is the restroom?
# predict :  Where is the restroom ?
# -------------------------------------------------------------------------------
# input : 도와주실 수 있나요?
# output : Can you help me?
# predict :  Can you help me ?
# -------------------------------------------------------------------------------
# input : 이해하지 못했어요.
# output : I don’t understand.
# predict :  I do n’t understand .
# -------------------------------------------------------------------------------
# input : 천천히 말씀해 주세요.
# output : Please speak slowly.
# predict :  Please speak slowly .
# -------------------------------------------------------------------------------
# input : 배고파요.
# output : I’m hungry.
# predict :  I ’m hungry .
# -------------------------------------------------------------------------------
# input : 피곤해요.
# output : I’m tired.
# predict :  I ’m tired .
# -------------------------------------------------------------------------------
# input : 지금 몇 시예요?
# output : What time is it?
# predict :  What time is it ?
# -------------------------------------------------------------------------------
# input : 오늘은 월요일이에요.
# output : Today is Monday.
# predict :  Today is Monday .
# -------------------------------------------------------------------------------
# input : 비가 오고 있어요.
# output : It’s raining.
# predict :  It ’s raining .
# -------------------------------------------------------------------------------
# input : 저는 음악을 좋아해요.
# output : I like music.
# predict :  I like music .
# -------------------------------------------------------------------------------
# input : 같이 가요.
# output : Let’s go together.
# predict :  Let ’s go together .
# -------------------------------------------------------------------------------
# input : 좋은 하루 되세요!
# output : Have a nice day!
# predict :  Have a nice day !
# -------------------------------------------------------------------------------
# input : 안녕히 가세요!
# output : Goodbye!
# predict :  Goodbye !
# -------------------------------------------------------------------------------
