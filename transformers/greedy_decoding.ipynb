# %% [markdown]
# ✅ 추천 블로그 및 자료
# 1. SanJaya Subedi – “Decoding strategies in Decoder models (LLMs)”
# Transformer decoder를 직접 구현하고, Greedy, Top‑K, Top‑P sampling 등의 디코딩 방식을 비교합니다.
#
# Greedy 방식이 어떻게 동작하는지 코드 예시가 포함되어 있어 실제 구조를 이해하는 데 좋습니다.
# GitHub
# +6
# KiKaBeN
# +6
# Christian Mills
# +6
# Niklas Heidloff
# +4
# Sanjaya's Blog
# +4
# Read Medium articles with AI
# +4
#
# 2. Hugging Face – “Decoding Strategies in Large Language Models”
# Greedy search와 Beam search, Top‑K & Top‑P 등에 대해 시각적으로 잘 정리되어 있습니다.
#
# 특히 LLM 추론에서 이런 기법들이 어떤 역할을 하는지 아티클 형태로 설명해 줍니다.
# Scaler
# +4
# Hugging Face
# +4
# Zenn
# +4
#
# 3. Scaler Topics – “Decoding Strategies for Transformers”
# greedy decoding의 특징, 장단점(속도 vs 문장 질), beam search 대비 설명이 간결하면서도 핵심적입니다.
# pi-tau
# +2
# No regret Just Lesson
# +2
# MachineLearningMastery.com
# +2
#
# 🔄 왜 이 자료들이 유용한가?
# 코드 + 이론: SanJaya Subedi 블로그는 Transformer decoding 구조를 '직접 구현'한 코드와 함께 설명해 실제 흐름을 파악하기에 적합합니다.
#
# 구조 비교: Hugging Face 및 Scaler의 글은 greedy decoding이 beam search 등과 어떻게 다른지, 어떤 상황에 적합한지 시각·이론적으로 비교해줍니다.
#
# 📚 추가 자료
# Graykode의 “Transformer (Greedy_decoder).ipynb/Py”
#
# Greedy decoder를 실제로 구현한 Colab 노트북과 Python 스크립트 코드가 포함되어 있어 실습용으로 좋습니다.
#
# GitHub 구현 확인 가능
# Sanjaya's Blog
# +1
# Sanjaya's Blog
# +1
# Scaler
# Google Colab
# +1
# GitHub
# +1
#
# Christian Mills – “Notes on Transformers Book Ch. 5”
#
# greedy decoding의 한계(반복, 최적 경로 미제공 등)를 요약해 설명합니다.
#
# Greedy 방식이 언제 적절한지 맥락 정리에 유용합니다.
# Niklas Heidloff
# +7
# Christian Mills
# +7
# KiKaBeN
# +7
#
# 요약하면:
#
# 코드 기반으로 구조를 이해하고 싶다면 → SanJaya Subedi, Graykode,
#
# 이론 + 비교를 보고 싶다면 → Hugging Face, Scaler, Christian Mills
#
# 더 깊이 있는 논문이나 추가 코드 예시가 필요하시면 언제든 말씀해 주세요! 😊
